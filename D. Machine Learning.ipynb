# %% [markdown]
# # Machine Learning

# %%
# Import required packages

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

sns.set()

# %%
# Read the previous csv file as dataframe
df = pd.read_csv('data.csv').drop(['Unnamed: 0'],axis=1)
df.head()
# Out:
#   InvoiceDate StockCode  Quantity  TotalPrice  Week  Weekday  Day  UnitPrice
# 0  2010-12-01     10002        60       51.00    48        2    1       0.85
# 1  2010-12-01     10125         2        1.70    48        2    1       0.85
# 2  2010-12-01     10133         5        4.25    48        2    1       0.85
# 3  2010-12-01    15044B         1        2.95    48        2    1       2.95
# 4  2010-12-01   15056BL        20      113.00    48        2    1       5.65

# %% [markdown]
# #### Our final dataset is ready to carry out machine learning operations.

# %% [markdown]
# ## Machine Learning Process and Methodology
#
# To find the best model for our purpose, we will train our data on different algorithms, compare their performance based on the Root mean square error of the prediction and time taken to fit/predict the model, and select the best.
#
# ### Algorithms employed:
# 1. Linear Regression
# 2. Regularization Model - Ridge
# 3. Regularization Model - Lasso
# 4. Ensemble Model - Random Forest
# 1. Ensemble Model - Gradient Boost
# 1. Ensemble Model - Ada Boost
#
# After training and evaluating our data on the above algorithms, we will also use model stacking.
#
# 7. Stack - Linear Regression
# 8. Stack - Random Forest
# 9. Stack - Gradient Boost

# %% [markdown]
# ### Train-test split
#
# We will hold out the data for last month from Nov-01-2011 to Dec-09-2011 as our test set, and the remaining data will be used to train our model.

# %%
# Split the dataset into train and test dataset

df_train = df[df.InvoiceDate<'2011-11-01']
df_test = df[df.InvoiceDate>='2011-11-01']

# %%
df_train.head()
# Out:
#   InvoiceDate StockCode  Quantity  TotalPrice  Week  Weekday  Day  UnitPrice
# 0  2010-12-01     10002        60       51.00    48        2    1       0.85
# 1  2010-12-01     10125         2        1.70    48        2    1       0.85
# 2  2010-12-01     10133         5        4.25    48        2    1       0.85
# 3  2010-12-01    15044B         1        2.95    48        2    1       2.95
# 4  2010-12-01   15056BL        20      113.00    48        2    1       5.65

# %%
# Define the feature and target variables

X_train = df_train.drop(labels=['InvoiceDate','StockCode','Quantity','TotalPrice'],axis=1)
y_train = df_train.Quantity

X_test = df_test.drop(labels=['InvoiceDate','StockCode','Quantity','TotalPrice'],axis=1)
y_test = df_test.Quantity

# %%
# Data Frame to store all the RMSE scores for various algorithms
algo_score = pd.DataFrame()
algo_score.index.name = 'Modelling Algo'
algo_score['Train RMSE'] = None
algo_score['Test RMSE'] = None
algo_score['Hyperparameters'] = None
algo_score['Training+Test Time(sec)'] = None

cv_time = []

# Dataframes for second level of predictions. Collect the predicted y values for training and test set of data
ypred_train = pd.DataFrame(index = X_train.index)
ypred_test = pd.DataFrame(index = X_test.index)

ypred_train['quantity'], ypred_test['quantity'] = y_train, y_test

# %% [markdown]
# We will define functions to measure the model, apply cross validation, and predict on train and test datasets. We have not included model fitting in the functions as that will happen as part of hyperparameter tuning

# %%
from sklearn.metrics import make_scorer

# Metric used to measure the model (Root Mean Square Error)
def rmse(y_actual, y_pred):
    rmse = np.sqrt(mean_squared_error(y_actual,y_pred))
    return rmse
rmse_cv = make_scorer(rmse, greater_is_better=False)

# %% [markdown]
# plot_true_vs_pred: This is used to plot True and Predicted count values for a particular time interval

# %%
# Plots True vs. Predicted count values
def plot_true_vs_pred (y_actual, y_pred):
    fig = plt.figure(figsize=(18, 16))
    
    pred_val = pd.DataFrame({'actual':y_actual,'predicted':y_pred})
    pred_val['error']=abs(pred_val.actual-pred_val.predicted)
    sns.swarmplot(pred_val.actual.round(0),pred_val.error)
    
    plt.show()

# %%
# Function to predict on train and test data and return the required metrics
def model_fit(model, X_train, y_train, X_test, y_test):
    ''' 
    Input:
        model = model to be applied
        X_train y_train = Training data
        X_test, y_test = Testing data
    Output:
        rmse for training and test data 
        predicted y for training and test data
    
    '''
#     model.fit(X_train, y_train)
    y_train_predict = model.predict(X_train)
    y_test_predict = model.predict(X_test)
    
    rmse_train = rmse(y_train, y_train_predict)
    rmse_test = rmse(y_test, y_test_predict)
    
    rmse_all = [rmse_train, rmse_test]
    y_pred_all = [y_train_predict, y_test_predict]
    
    return(rmse_all, y_pred_all)

# %%
from sklearn.model_selection import cross_val_predict
def cross_val(model, X_train, y_train, cv=5):
#     y_pred = pd.Series(index=y_train.index)
    y_pred = cross_val_predict(model,X_train,y_train,cv=5)

    rmse_train = rmse(y_train,y_pred)
    return(rmse_train, y_pred)

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression

reg = LinearRegression()

param_summary = ['','']

# %time reg.fit(X_train, y_train)
# %time rmse_summary, y_predict_summary = model_fit(reg, X_train, y_train, X_test, y_test)

ypred_test['LR'] = y_predict_summary[1]  
ypred_train['LR'] = y_predict_summary[0]

algo_score.loc['Linear Regression'] = rmse_summary+param_summary
# Out:
# Wall time: 398 ms
# Wall time: 118 ms

# %%
algo_score.loc['Linear Regression', 'Training+Test Time(sec)'] = 0.516
cv_time.append(0.516)
algo_score
# Out:
#                    Train RMSE  Test RMSE  \
# Modelling Algo
# Random Forest       19.004094  22.758548
# Linear Regression   25.033909  25.931982
#
#                                                      Hyperparameters  \
# Modelling Algo
# Random Forest      {'n_jobs': -1, 'n_estimators': 500, 'min_sampl...
# Linear Regression
#
#                   Training+Test Time(sec)
# Modelling Algo
# Random Forest                        6706
# Linear Regression                   0.516

# %% [markdown]
# #### Observations
#
# Not an overfit model - both train and test RMSE are more or less similar

# %%
# Features and the Estimated Linear Regression Coefficients
df_coeff = pd.DataFrame({'features': X_train.columns, 'Lin_Coeff': reg.coef_})

# %%
# Linear Regression Plot: True vs. Predicted
# plot_true_vs_pred(y_test,y_predict_summary[1])

# %% [markdown]
# ### Regularization Model - Ridge

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV

# Hyperparameter Tuning
param_grid = {'alpha': [0.1, 0.2, 0.5, 1, 2, 5, 10, 20, 50, 100]}
ridge = GridSearchCV(Ridge(random_state=42), param_grid, cv=5, scoring=rmse_cv)
# %time ridge.fit(X_train, y_train)
print('Best alpha for Ridge Regression Model: {}'.format(ridge.best_params_))
# Out:
# Wall time: 3.87 s
# Best alpha for Ridge Regression Model: {'alpha': 100}

# %%
# Fine tune Hyperparameter for edge cases
param_grid = {'alpha': np.arange(75,150,10)}
ridge = GridSearchCV(Ridge(random_state=42), param_grid, cv=5, scoring=rmse_cv)
# %time ridge.fit(X_train, y_train)
print('Best alpha for Ridge Regression Model: {}'.format(ridge.best_params_))
# Out:
# Wall time: 2.95 s
# Best alpha for Ridge Regression Model: {'alpha': 145}

# %%
param_summary = [ridge.best_params_,'']

# %time rmse_summary, y_predict_summary = model_fit(ridge, X_train, y_train, X_test, y_test)

ypred_test['Ridge'] = y_predict_summary[1]  
ypred_train['Ridge'] = y_predict_summary[0]

algo_score.loc['Ridge Regression'] = rmse_summary+param_summary
# Out:
# Wall time: 96.8 ms

# %%
algo_score.loc['Ridge Regression', 'Training+Test Time(sec)'] = 6.917
cv_time.append(6.917)
algo_score
# Out:
#                    Train RMSE  Test RMSE  \
# Modelling Algo
# Random Forest       19.004094  22.758548
# Linear Regression   25.033909  25.931982
# Ridge Regression    25.033909  25.931989
#
#                                                      Hyperparameters  \
# Modelling Algo
# Random Forest      {'n_jobs': -1, 'n_estimators': 500, 'min_sampl...
# Linear Regression
# Ridge Regression                                      {'alpha': 145}
#
#                   Training+Test Time(sec)
# Modelling Algo
# Random Forest                        6706
# Linear Regression                   0.516
# Ridge Regression                    6.917

# %% [markdown]
# #### Observations
#
# Ridge gives almost similar performance as Linear Regression. It is not an overfit model

# %%
# Features and the Estimated Ridge Regression Coefficients
df_coeff['Ridge_Coeff'] = ridge.best_estimator_.coef_

# %%
# plot_true_vs_pred(y_test,y_predict_summary[1])

# %% [markdown]
# ### Regularization Model - Lasso

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV

# Hyperparameter Tuning
param_grid = {'alpha': [0.1, 0.2, 0.5, 1, 2, 5, 10, 20, 50, 100]}
lasso = GridSearchCV(Lasso(random_state=42), param_grid, cv=5, scoring=rmse_cv)
# %time lasso.fit(X_train, y_train)
print('Best alpha for Lasso Regression Model: {}'.format(lasso.best_params_))
# Out:
# Wall time: 13.9 s
# Best alpha for Lasso Regression Model: {'alpha': 0.2}

# %%
# Fine tune Hyperparameter for edge case

param_grid = {'alpha': np.arange(.01,.25,.01)}
lasso = GridSearchCV(Lasso(random_state=42), param_grid, cv=5, scoring=rmse_cv)
# %time lasso.fit(X_train, y_train)
print('Best alpha for Lasso Regression Model: {}'.format(lasso.best_params_))
# Out:
# Wall time: 17.4 s
# Best alpha for Lasso Regression Model: {'alpha': 0.22}

# %%
param_summary = [lasso.best_params_,'']

# %time rmse_summary, y_predict_summary = model_fit(lasso, X_train, y_train, X_test, y_test)
ypred_test['Lasso'] = y_predict_summary[1]
ypred_train['Lasso'] = y_predict_summary[0]

algo_score.loc['Lasso Regression'] = rmse_summary+param_summary
# Out:
# Wall time: 27.9 ms

# %%
algo_score.loc['Lasso Regression', 'Training+Test Time(sec)'] = 31.328
cv_time.append(31.328)
algo_score
# Out:
#                    Train RMSE  Test RMSE  \
# Modelling Algo
# Random Forest       19.004094  22.758548
# Linear Regression   25.033909  25.931982
# Ridge Regression    25.033909  25.931989
# Lasso Regression    25.034230  25.933011
#
#                                                      Hyperparameters  \
# Modelling Algo
# Random Forest      {'n_jobs': -1, 'n_estimators': 500, 'min_sampl...
# Linear Regression
# Ridge Regression                                      {'alpha': 145}
# Lasso Regression                                     {'alpha': 0.22}
#
#                   Training+Test Time(sec)
# Modelling Algo
# Random Forest                        6706
# Linear Regression                   0.516
# Ridge Regression                    6.917
# Lasso Regression                   31.328

# %% [markdown]
# #### Observations
#
# Lasso regression also shows almost similar performance as Linear and Ridge regression

# %%
# Features and the Estimated Lasso Regression Coefficients
df_coeff['Lasso_Coeff'] = lasso.best_estimator_.coef_

# %%
# plot_true_vs_pred(y_test,y_predict_summary[1])

# %% [markdown]
# ### Plotting the coefficients obtained from Linear, Ridge and Lasso regression

# %%
fig = plt.figure(figsize=(10, 5))

axes = fig.add_subplot(1, 1, 1)
axes.plot(df_coeff.Lin_Coeff, label='Linear Regression', marker='.', markersize=15)
axes.plot(df_coeff.Ridge_Coeff, label='Ridge Regression, alpha={}'.format(ridge.best_params_['alpha']), alpha=.5,marker='.', markersize=15)
axes.plot(df_coeff.Lasso_Coeff, label='Lasso Regression, alpha={}'.format(lasso.best_params_['alpha']), marker='.', markersize=15)

plt.xticks(range(len(df_coeff.Lin_Coeff)), df_coeff.features, rotation=90)
axes.set(ylabel='Estimated Regression Coefficients', title='Coefficients for different models')
axes.set(xlim=[-1, len(df_coeff.Lin_Coeff)])
axes.legend()

# %% [markdown]
# #### Observations
#
# As seen above, Weekday and UnitPrice are most important features

# %% [markdown]
# ### Ensemble Model - Random Forest

# %%
# Random Forest Regression Hyperparameter tuning using Grid Search to obtain the best parameters. 

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

# %%
# The code for hyperparameter tuning is commented out as it takes a long time to run 

# Tuning the hyperparameters

# param_distributions = {'n_estimators': [50,500,1000], 'max_features':['auto'], 'min_samples_leaf':[1,10,50],'n_jobs':[-1]}
# rf_main = RandomizedSearchCV(RandomForestRegressor(random_state=42), param_distributions, verbose=2, n_iter = 50,cv=5, 
#                              scoring=rmse_cv)
# %time rf_main.fit(X_train, y_train)
# Out:
# C:\Users\sony\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:271: UserWarning: The total space of parameters 9 is smaller than n_iter=50. Running 9 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] n_jobs=-1, n_estimators=50, min_samples_leaf=1, max_features=auto
# [CV]  n_jobs=-1, n_estimators=50, min_samples_leaf=1, max_features=auto, total=  25.6s
# [CV] n_jobs=-1, n_estimators=50, min_samples_leaf=1, max_features=auto
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   27.1s remaining:    0.0s
# [CV]  n_jobs=-1, n_estimators=50, min_samples_leaf=1, max_features=auto, total=  18.7s
# [CV] n_jobs=-1, n_estimators=50, min_samples_leaf=1, max_features=auto
# [CV]  n_jobs=-1, n_estimators=50, min_samples_leaf=1, max_features=auto, total=  31.7s
# [CV] n_jobs=-1, n_estimators=50, min_samples_leaf=1, max_features=auto
# [CV]  n_jobs=-1, n_estimators=50, min_samples_leaf=1, max_features=auto, total=  10.0s
# [CV] n_jobs=-1, n_estimators=50, min_samples_leaf=1, max_features=auto
# [CV]  n_jobs=-1, n_estimators=50, min_samples_leaf=1, max_features=auto, total=   8.7s
# [CV] n_jobs=-1, n_estimators=500, min_samples_leaf=1, max_features=auto
# [CV]  n_jobs=-1, n_estimators=500, min_samples_leaf=1, max_features=auto, total= 2.7min
# [CV] n_jobs=-1, n_estimators=500, min_samples_leaf=1, max_features=auto
# [CV]  n_jobs=-1, n_estimators=500, min_samples_leaf=1, max_features=auto, total= 2.2min
# [CV] n_jobs=-1, n_estimators=500, min_samples_leaf=1, max_features=auto
# [CV]  n_jobs=-1, n_estimators=500, min_samples_leaf=1, max_features=auto, total= 2.2min
# [CV] n_jobs=-1, n_estimators=500, min_samples_leaf=1, max_features=auto
# [CV]  n_jobs=-1, n_estimators=500, min_samples_leaf=1, max_features=auto, total= 2.3min
# [CV] n_jobs=-1, n_estimators=500, min_samples_leaf=1, max_features=auto
# [CV]  n_jobs=-1, n_estimators=500, min_samples_leaf=1, max_features=auto, total= 2.1min
# [CV] n_jobs=-1, n_estimators=1000, min_samples_leaf=1, max_features=auto
# [CV]  n_jobs=-1, n_estimators=1000, min_samples_leaf=1, max_features=auto, total= 4.2min
# [CV] n_jobs=-1, n_estimators=1000, min_samples_leaf=1, max_features=auto
# [CV]  n_jobs=-1, n_estimators=1000, min_samples_leaf=1, max_features=auto, total= 4.5min
# [CV] n_jobs=-1, n_estimators=1000, min_samples_leaf=1, max_features=auto
# [CV]  n_jobs=-1, n_estimators=1000, min_samples_leaf=1, max_features=auto, total= 4.1min
# [CV] n_jobs=-1, n_estimators=1000, min_samples_leaf=1, max_features=auto
# [CV]  n_jobs=-1, n_estimators=1000, min_samples_leaf=1, max_features=auto, total= 5.3min
# [CV] n_jobs=-1, n_estimators=1000, min_samples_leaf=1, max_features=auto
# [CV]  n_jobs=-1, n_estimators=1000, min_samples_leaf=1, max_features=auto, total= 4.8min
# [CV] n_jobs=-1, n_estimators=50, min_samples_leaf=10, max_features=auto
# [CV]  n_jobs=-1, n_estimators=50, min_samples_leaf=10, max_features=auto, total=  19.7s
# [CV] n_jobs=-1, n_estimators=50, min_samples_leaf=10, max_features=auto
# [CV]  n_jobs=-1, n_estimators=50, min_samples_leaf=10, max_features=auto, total=   8.6s
# [CV] n_jobs=-1, n_estimators=50, min_samples_leaf=10, max_features=auto
# [CV]  n_jobs=-1, n_estimators=50, min_samples_leaf=10, max_features=auto, total=   6.9s
# [CV] n_jobs=-1, n_estimators=50, min_samples_leaf=10, max_features=auto
# [CV]  n_jobs=-1, n_estimators=50, min_samples_leaf=10, max_features=auto, total=   6.8s
# [CV] n_jobs=-1, n_estimators=50, min_samples_leaf=10, max_features=auto
# [CV]  n_jobs=-1, n_estimators=50, min_samples_leaf=10, max_features=auto, total=  12.3s
# [CV] n_jobs=-1, n_estimators=500, min_samples_leaf=10, max_features=auto
# [CV]  n_jobs=-1, n_estimators=500, min_samples_leaf=10, max_features=auto, total= 1.7min
# [CV] n_jobs=-1, n_estimators=500, min_samples_leaf=10, max_features=auto
# [CV]  n_jobs=-1, n_estimators=500, min_samples_leaf=10, max_features=auto, total= 2.3min
# [CV] n_jobs=-1, n_estimators=500, min_samples_leaf=10, max_features=auto
# [CV]  n_jobs=-1, n_estimators=500, min_samples_leaf=10, max_features=auto, total= 2.0min
# [CV] n_jobs=-1, n_estimators=500, min_samples_leaf=10, max_features=auto
# [CV]  n_jobs=-1, n_estimators=500, min_samples_leaf=10, max_features=auto, total= 2.1min
# [CV] n_jobs=-1, n_estimators=500, min_samples_leaf=10, max_features=auto
# [CV]  n_jobs=-1, n_estimators=500, min_samples_leaf=10, max_features=auto, total= 2.3min
# [CV] n_jobs=-1, n_estimators=1000, min_samples_leaf=10, max_features=auto
# [CV]  n_jobs=-1, n_estimators=1000, min_samples_leaf=10, max_features=auto, total= 4.6min
# [CV] n_jobs=-1, n_estimators=1000, min_samples_leaf=10, max_features=auto
# [CV]  n_jobs=-1, n_estimators=1000, min_samples_leaf=10, max_features=auto, total= 4.6min
# [CV] n_jobs=-1, n_estimators=1000, min_samples_leaf=10, max_features=auto
# [CV]  n_jobs=-1, n_estimators=1000, min_samples_leaf=10, max_features=auto, total= 4.2min
# [CV] n_jobs=-1, n_estimators=1000, min_samples_leaf=10, max_features=auto
# [CV]  n_jobs=-1, n_estimators=1000, min_samples_leaf=10, max_features=auto, total= 4.0min
# [CV] n_jobs=-1, n_estimators=1000, min_samples_leaf=10, max_features=auto
# [CV]  n_jobs=-1, n_estimators=1000, min_samples_leaf=10, max_features=auto, total= 4.1min
# [CV] n_jobs=-1, n_estimators=50, min_samples_leaf=50, max_features=auto
# [CV]  n_jobs=-1, n_estimators=50, min_samples_leaf=50, max_features=auto, total=  10.6s
# [CV] n_jobs=-1, n_estimators=50, min_samples_leaf=50, max_features=auto
# [CV]  n_jobs=-1, n_estimators=50, min_samples_leaf=50, max_features=auto, total=  20.2s
# [CV] n_jobs=-1, n_estimators=50, min_samples_leaf=50, max_features=auto
# [CV]  n_jobs=-1, n_estimators=50, min_samples_leaf=50, max_features=auto, total=  14.0s
# [CV] n_jobs=-1, n_estimators=50, min_samples_leaf=50, max_features=auto
# [CV]  n_jobs=-1, n_estimators=50, min_samples_leaf=50, max_features=auto, total=   6.7s
# [CV] n_jobs=-1, n_estimators=50, min_samples_leaf=50, max_features=auto
# [CV]  n_jobs=-1, n_estimators=50, min_samples_leaf=50, max_features=auto, total=   6.7s
# [CV] n_jobs=-1, n_estimators=500, min_samples_leaf=50, max_features=auto
# [CV]  n_jobs=-1, n_estimators=500, min_samples_leaf=50, max_features=auto, total= 1.9min
# [CV] n_jobs=-1, n_estimators=500, min_samples_leaf=50, max_features=auto
# [CV]  n_jobs=-1, n_estimators=500, min_samples_leaf=50, max_features=auto, total= 1.5min
# [CV] n_jobs=-1, n_estimators=500, min_samples_leaf=50, max_features=auto
# [CV]  n_jobs=-1, n_estimators=500, min_samples_leaf=50, max_features=auto, total= 1.6min
# [CV] n_jobs=-1, n_estimators=500, min_samples_leaf=50, max_features=auto
# [CV]  n_jobs=-1, n_estimators=500, min_samples_leaf=50, max_features=auto, total= 2.0min
# [CV] n_jobs=-1, n_estimators=500, min_samples_leaf=50, max_features=auto
# [CV]  n_jobs=-1, n_estimators=500, min_samples_leaf=50, max_features=auto, total= 2.2min
# [CV] n_jobs=-1, n_estimators=1000, min_samples_leaf=50, max_features=auto
# [CV]  n_jobs=-1, n_estimators=1000, min_samples_leaf=50, max_features=auto, total= 4.7min
# [CV] n_jobs=-1, n_estimators=1000, min_samples_leaf=50, max_features=auto
# [CV]  n_jobs=-1, n_estimators=1000, min_samples_leaf=50, max_features=auto, total= 5.0min
# [CV] n_jobs=-1, n_estimators=1000, min_samples_leaf=50, max_features=auto
# [CV]  n_jobs=-1, n_estimators=1000, min_samples_leaf=50, max_features=auto, total= 3.6min
# [CV] n_jobs=-1, n_estimators=1000, min_samples_leaf=50, max_features=auto
# [CV]  n_jobs=-1, n_estimators=1000, min_samples_leaf=50, max_features=auto, total= 3.5min
# [CV] n_jobs=-1, n_estimators=1000, min_samples_leaf=50, max_features=auto
# [CV]  n_jobs=-1, n_estimators=1000, min_samples_leaf=50, max_features=auto, total= 3.3min
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed: 109.1min finished
# Wall time: 1h 51min 21s
# RandomizedSearchCV(cv=5, error_score='raise-deprecating',
#           estimator=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#            oob_score=False, random_state=42, verbose=0, warm_start=False),
#           fit_params=None, iid='warn', n_iter=50, n_jobs=None,
#           param_distributions={'n_estimators': [50, 500, 1000], 'max_features': ['auto'], 'min_samples_leaf': [1, 10, 50], 'n_jobs': [-1]},
#           pre_dispatch='2*n_jobs', random_state=None, refit=True,
#           return_train_score='warn',
#           scoring=make_scorer(rmse, greater_is_better=False), verbose=2)

# %%
print('Best parameters for Random Forest Regression Model: {}'.format(rf_main.best_params_))
# Out:
# Best parameters for Random Forest Regression Model: {'n_jobs': -1, 'n_estimators': 500, 'min_samples_leaf': 50, 'max_features': 'auto'}

# %% [markdown]
# Best parameters for Random Forest Regression Model: {'n_jobs': -1, 'n_estimators': 500, 'min_samples_leaf': 50, 'max_features': 'auto'}

# %%
param_summary = [rf_main.best_params_,'']

# %time rmse_summary, y_predict_summary = model_fit(rf_main, X_train, y_train, X_test, y_test)
ypred_test['RF'] = y_predict_summary[1]
ypred_train['RF'] = y_predict_summary[0]

algo_score.loc['Random Forest'] = rmse_summary+param_summary
# Out:
# Wall time: 25 s

# %%
algo_score.loc['Random Forest', 'Training+Test Time(sec)'] = 6706
cv_time.append(6706)
algo_score
# Out:
#                 Train RMSE  Test RMSE  \
# Modelling Algo
# Random Forest    19.004094  22.758548
#
#                                                   Hyperparameters  \
# Modelling Algo
# Random Forest   {'n_jobs': -1, 'n_estimators': 500, 'min_sampl...
#
#                 Training+Test Time(sec)
# Modelling Algo
# Random Forest                      6706

# %% [markdown]
# ### Visualize the mean score against different values for n estimators
#
# Parts of code have been commenting out as they take long time to execute

# %%
rf_result=pd.DataFrame(rf_main.cv_results_)
rf_result
# Out:
# C:\Users\sony\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split0_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\sony\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split1_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\sony\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split2_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\sony\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split3_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\sony\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split4_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\sony\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\sony\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('std_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_n_jobs  \
# 0      18.558974      8.786616         0.466934        0.301231           -1
# 1     130.990396      7.718866         7.520009        7.033009           -1
# 2     253.149989     13.749022        21.902282       12.616121           -1
# 3      10.606782      4.708042         0.341567        0.150922           -1
# 4     123.127211     13.866596         2.964986        1.590349           -1
# 5     248.583497     17.299661         9.442348        4.383220           -1
# 6      11.454806      4.976094         0.300542        0.155584           -1
# 7     108.072299     15.804555         2.372789        1.492850           -1
# 8     238.210080     40.217046         4.028293        2.040201           -1
#
#   param_n_estimators param_min_samples_leaf param_max_features  \
# 0                 50                      1               auto
# 1                500                      1               auto
# 2               1000                      1               auto
# 3                 50                     10               auto
# 4                500                     10               auto
# 5               1000                     10               auto
# 6                 50                     50               auto
# 7                500                     50               auto
# 8               1000                     50               auto
#
#                                               params  split0_test_score  \
# 0  {'n_jobs': -1, 'n_estimators': 50, 'min_sample...         -19.838989
# 1  {'n_jobs': -1, 'n_estimators': 500, 'min_sampl...         -19.790652
# 2  {'n_jobs': -1, 'n_estimators': 1000, 'min_samp...         -19.799622
# 3  {'n_jobs': -1, 'n_estimators': 50, 'min_sample...         -19.542392
# 4  {'n_jobs': -1, 'n_estimators': 500, 'min_sampl...         -19.531595
# 5  {'n_jobs': -1, 'n_estimators': 1000, 'min_samp...         -19.529503
# 6  {'n_jobs': -1, 'n_estimators': 50, 'min_sample...         -19.466177
# 7  {'n_jobs': -1, 'n_estimators': 500, 'min_sampl...         -19.439153
# 8  {'n_jobs': -1, 'n_estimators': 1000, 'min_samp...         -19.441185
#
#         ...         mean_test_score  std_test_score  rank_test_score  \
# 0       ...              -20.294823        1.513568                9
# 1       ...              -20.210575        1.472068                7
# 2       ...              -20.211140        1.467786                8
# 3       ...              -20.055164        1.495588                6
# 4       ...              -20.027074        1.487825                3
# 5       ...              -20.028710        1.491023                4
# 6       ...              -20.032161        1.403155                5
# 7       ...              -20.016103        1.391165                1
# 8       ...              -20.017136        1.393444                2
#
#    split0_train_score  split1_train_score  split2_train_score  \
# 0          -16.297452          -16.494141          -16.315227
# 1          -16.261173          -16.460695          -16.279026
# 2          -16.258161          -16.459263          -16.278677
# 3          -18.024577          -18.242408          -18.076695
# 4          -18.002964          -18.225101          -18.056364
# 5          -18.003714          -18.224482          -18.057427
# 6          -19.194025          -19.412267          -19.147918
# 7          -19.187802          -19.403599          -19.143975
# 8          -19.187768          -19.403759          -19.145287
#
#    split3_train_score  split4_train_score  mean_train_score  std_train_score
# 0          -16.235362          -15.872048        -16.242846         0.204410
# 1          -16.205820          -15.845328        -16.210408         0.201610
# 2          -16.204360          -15.842770        -16.208646         0.202014
# 3          -17.977153          -17.453830        -17.954933         0.266051
# 4          -17.959808          -17.444349        -17.937717         0.262611
# 5          -17.958846          -17.443431        -17.937580         0.262939
# 6          -19.076141          -18.575321        -19.081134         0.276668
# 7          -19.067289          -18.573519        -19.075237         0.274591
# 8          -19.068167          -18.573157        -19.075628         0.274820
#
# [9 rows x 24 columns]

# %%
est_score = rf_result.groupby('param_n_estimators')['mean_test_score'].mean()
est_score
# Out:
# param_n_estimators
# 50     -20.127383
# 500    -20.084584
# 1000   -20.085662
# Name: mean_test_score, dtype: float64

# %%
fig=plt.figure(figsize=(18, 12))

axes=fig.add_subplot(2, 3, 1)
axes.plot(est_score.index, est_score.values, marker='.')
axes.set(xlabel='n_estimators', ylabel='Mean CV Test Score', title='n_estimators vs. Score (best_n_estimator = 500)')
# Out:
# [Text(0,0.5,'Mean CV Test Score'),
#  Text(0.5,0,'n_estimators'),
#  Text(0.5,1,'n_estimators vs. Score (best_n_estimator = 500)')]

# %%
fig = plt.figure(figsize=(18, 8))
axes = fig.add_subplot(1, 1, 1)
axes.plot(rf_main.best_estimator_.feature_importances_, marker='.', markersize=15)
plt.xticks(range(len(rf_main.best_estimator_.feature_importances_)), X_train.columns,rotation=90)
axes.set(ylabel='Feature Importance', title='Feature Importance for Random Forest Regression')

plt.show()

# %% [markdown]
# ### Ensemble Method - Gradient Boost

# %%
# The code for hyperparameter tuning is commented out as it takes a long time to run 

# Tuning the hyperparameters

from sklearn.ensemble import GradientBoostingRegressor

param_distributions = {'n_estimators': [50,100,500,1000], 'learning_rate':[0.01, 0.05, 0.1],'max_features':['auto'], 'min_samples_leaf':[1, 3, 7, 10], 'min_samples_split':[2,5,10]}
grad_boost = RandomizedSearchCV(GradientBoostingRegressor(random_state=42), param_distributions, verbose=2, n_iter = 100,cv=5, scoring=rmse_cv)
grad_boost.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] n_estimators=1000, min_samples_split=10, min_samples_leaf=7, max_features=auto, learning_rate=0.05
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  n_estimators=1000, min_samples_split=10, min_samples_leaf=7, max_features=auto, learning_rate=0.05, total= 2.0min
# [CV] n_estimators=1000, min_samples_split=10, min_samples_leaf=7, max_features=auto, learning_rate=0.05
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  2.1min remaining:    0.0s
# [CV]  n_estimators=1000, min_samples_split=10, min_samples_leaf=7, max_features=auto, learning_rate=0.05, total= 1.7min
# [CV] n_estimators=1000, min_samples_split=10, min_samples_leaf=7, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=1000, min_samples_split=10, min_samples_leaf=7, max_features=auto, learning_rate=0.05, total= 1.7min
# [CV] n_estimators=1000, min_samples_split=10, min_samples_leaf=7, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=1000, min_samples_split=10, min_samples_leaf=7, max_features=auto, learning_rate=0.05, total= 2.0min
# [CV] n_estimators=1000, min_samples_split=10, min_samples_leaf=7, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=1000, min_samples_split=10, min_samples_leaf=7, max_features=auto, learning_rate=0.05, total= 1.6min
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.1, total=  19.6s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.1, total=   8.3s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.1, total=   8.5s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.1, total=   8.0s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.1, total=  16.9s
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=10, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=10, max_features=auto, learning_rate=0.01, total= 1.6min
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=10, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=10, max_features=auto, learning_rate=0.01, total= 1.5min
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=10, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=10, max_features=auto, learning_rate=0.01, total= 2.3min
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=10, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=10, max_features=auto, learning_rate=0.01, total= 2.2min
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=10, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=10, max_features=auto, learning_rate=0.01, total= 2.0min
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=7, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=7, max_features=auto, learning_rate=0.05, total= 2.0min
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=7, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=7, max_features=auto, learning_rate=0.05, total= 2.0min
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=7, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=7, max_features=auto, learning_rate=0.05, total= 1.9min
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=7, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=7, max_features=auto, learning_rate=0.05, total= 1.9min
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=7, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=7, max_features=auto, learning_rate=0.05, total= 1.8min
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.1, total= 1.7min
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.1, total= 1.9min
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.1, total= 1.8min
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.1, total= 1.9min
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.1, total= 1.7min
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.05, total=  19.8s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.05, total=   8.3s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.05, total=   8.8s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.05, total=  11.0s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.05, total=  20.9s
# [CV] n_estimators=50, min_samples_split=10, min_samples_leaf=3, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=50, min_samples_split=10, min_samples_leaf=3, max_features=auto, learning_rate=0.05, total=   6.9s
# [CV] n_estimators=50, min_samples_split=10, min_samples_leaf=3, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=50, min_samples_split=10, min_samples_leaf=3, max_features=auto, learning_rate=0.05, total=   4.2s
# [CV] n_estimators=50, min_samples_split=10, min_samples_leaf=3, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=50, min_samples_split=10, min_samples_leaf=3, max_features=auto, learning_rate=0.05, total=   4.3s
# [CV] n_estimators=50, min_samples_split=10, min_samples_leaf=3, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=50, min_samples_split=10, min_samples_leaf=3, max_features=auto, learning_rate=0.05, total=   4.4s
# [CV] n_estimators=50, min_samples_split=10, min_samples_leaf=3, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=50, min_samples_split=10, min_samples_leaf=3, max_features=auto, learning_rate=0.05, total=   4.7s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.1, total=   8.1s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.1, total=  16.2s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.1, total=  19.1s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.1, total=   7.9s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.1, total=   8.3s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.01, total= 1.2min
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.01, total=  46.8s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.01, total=  45.5s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.01, total=  52.7s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.01, total=  45.3s
# [CV] n_estimators=500, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.1, total= 1.0min
# [CV] n_estimators=500, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.1, total=  49.3s
# [CV] n_estimators=500, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.1, total=  53.7s
# [CV] n_estimators=500, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.1, total= 1.1min
# [CV] n_estimators=500, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.1, total= 1.2min
# [CV] n_estimators=1000, min_samples_split=10, min_samples_leaf=1, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=1000, min_samples_split=10, min_samples_leaf=1, max_features=auto, learning_rate=0.1, total= 2.2min
# [CV] n_estimators=1000, min_samples_split=10, min_samples_leaf=1, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=1000, min_samples_split=10, min_samples_leaf=1, max_features=auto, learning_rate=0.1, total= 2.0min
# [CV] n_estimators=1000, min_samples_split=10, min_samples_leaf=1, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=1000, min_samples_split=10, min_samples_leaf=1, max_features=auto, learning_rate=0.1, total= 2.1min
# [CV] n_estimators=1000, min_samples_split=10, min_samples_leaf=1, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=1000, min_samples_split=10, min_samples_leaf=1, max_features=auto, learning_rate=0.1, total= 2.0min
# [CV] n_estimators=1000, min_samples_split=10, min_samples_leaf=1, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=1000, min_samples_split=10, min_samples_leaf=1, max_features=auto, learning_rate=0.1, total= 1.8min
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=10, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=10, max_features=auto, learning_rate=0.05, total=  17.7s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=10, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=10, max_features=auto, learning_rate=0.05, total=  23.5s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=10, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=10, max_features=auto, learning_rate=0.05, total=   8.3s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=10, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=10, max_features=auto, learning_rate=0.05, total=   8.0s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=10, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=10, max_features=auto, learning_rate=0.05, total=   8.0s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.1, total=   7.5s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.1, total=  13.4s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.1, total=  21.8s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.1, total=  15.1s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.1, total=   8.1s
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.05, total= 1.7min
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.05, total= 2.0min
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.05, total= 2.4min
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.05, total= 1.8min
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.05, total= 1.8min
# [CV] n_estimators=500, min_samples_split=5, min_samples_leaf=10, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=500, min_samples_split=5, min_samples_leaf=10, max_features=auto, learning_rate=0.01, total=  45.7s
# [CV] n_estimators=500, min_samples_split=5, min_samples_leaf=10, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=500, min_samples_split=5, min_samples_leaf=10, max_features=auto, learning_rate=0.01, total=  58.2s
# [CV] n_estimators=500, min_samples_split=5, min_samples_leaf=10, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=500, min_samples_split=5, min_samples_leaf=10, max_features=auto, learning_rate=0.01, total=  48.5s
# [CV] n_estimators=500, min_samples_split=5, min_samples_leaf=10, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=500, min_samples_split=5, min_samples_leaf=10, max_features=auto, learning_rate=0.01, total= 1.2min
# [CV] n_estimators=500, min_samples_split=5, min_samples_leaf=10, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=500, min_samples_split=5, min_samples_leaf=10, max_features=auto, learning_rate=0.01, total= 1.3min
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.05, total=   7.4s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.05, total=   6.3s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.05, total=   7.6s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.05, total=   7.7s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.05, total=  22.1s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.1, total=  11.2s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.1, total=  10.7s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.1, total=  11.6s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.1, total=  10.1s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.1, total=   3.3s
# [CV] n_estimators=50, min_samples_split=10, min_samples_leaf=7, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=50, min_samples_split=10, min_samples_leaf=7, max_features=auto, learning_rate=0.05, total=   4.2s
# [CV] n_estimators=50, min_samples_split=10, min_samples_leaf=7, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=50, min_samples_split=10, min_samples_leaf=7, max_features=auto, learning_rate=0.05, total=   3.8s
# [CV] n_estimators=50, min_samples_split=10, min_samples_leaf=7, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=50, min_samples_split=10, min_samples_leaf=7, max_features=auto, learning_rate=0.05, total=   4.4s
# [CV] n_estimators=50, min_samples_split=10, min_samples_leaf=7, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=50, min_samples_split=10, min_samples_leaf=7, max_features=auto, learning_rate=0.05, total=   3.6s
# [CV] n_estimators=50, min_samples_split=10, min_samples_leaf=7, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=50, min_samples_split=10, min_samples_leaf=7, max_features=auto, learning_rate=0.05, total=   3.7s
# [CV] n_estimators=1000, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=1000, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.1, total= 2.0min
# [CV] n_estimators=1000, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=1000, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.1, total= 1.9min
# [CV] n_estimators=1000, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=1000, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.1, total= 2.3min
# [CV] n_estimators=1000, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=1000, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.1, total= 1.3min
# [CV] n_estimators=1000, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=1000, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.1, total= 1.5min
# [CV] n_estimators=500, min_samples_split=10, min_samples_leaf=1, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=500, min_samples_split=10, min_samples_leaf=1, max_features=auto, learning_rate=0.01, total=  44.3s
# [CV] n_estimators=500, min_samples_split=10, min_samples_leaf=1, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=500, min_samples_split=10, min_samples_leaf=1, max_features=auto, learning_rate=0.01, total=  57.9s
# [CV] n_estimators=500, min_samples_split=10, min_samples_leaf=1, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=500, min_samples_split=10, min_samples_leaf=1, max_features=auto, learning_rate=0.01, total=  57.7s
# [CV] n_estimators=500, min_samples_split=10, min_samples_leaf=1, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=500, min_samples_split=10, min_samples_leaf=1, max_features=auto, learning_rate=0.01, total=  30.9s
# [CV] n_estimators=500, min_samples_split=10, min_samples_leaf=1, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=500, min_samples_split=10, min_samples_leaf=1, max_features=auto, learning_rate=0.01, total=  32.8s
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=1, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=1, max_features=auto, learning_rate=0.05, total= 1.4min
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=1, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=1, max_features=auto, learning_rate=0.05, total= 1.4min
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=1, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=1, max_features=auto, learning_rate=0.05, total= 1.1min
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=1, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=1, max_features=auto, learning_rate=0.05, total= 1.5min
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=1, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=1, max_features=auto, learning_rate=0.05, total= 1.9min
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.1, total=   6.7s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.1, total=   6.8s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.1, total=   6.8s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.1, total=   6.6s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.1, total=   7.2s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=10, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=10, max_features=auto, learning_rate=0.01, total=  19.9s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=10, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=10, max_features=auto, learning_rate=0.01, total=  19.4s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=10, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=10, max_features=auto, learning_rate=0.01, total=  18.8s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=10, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=10, max_features=auto, learning_rate=0.01, total=  21.2s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=10, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=10, max_features=auto, learning_rate=0.01, total=  19.1s
# [CV] n_estimators=500, min_samples_split=10, min_samples_leaf=1, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=10, min_samples_leaf=1, max_features=auto, learning_rate=0.1, total= 1.3min
# [CV] n_estimators=500, min_samples_split=10, min_samples_leaf=1, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=10, min_samples_leaf=1, max_features=auto, learning_rate=0.1, total= 1.3min
# [CV] n_estimators=500, min_samples_split=10, min_samples_leaf=1, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=10, min_samples_leaf=1, max_features=auto, learning_rate=0.1, total= 1.4min
# [CV] n_estimators=500, min_samples_split=10, min_samples_leaf=1, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=10, min_samples_leaf=1, max_features=auto, learning_rate=0.1, total= 1.3min
# [CV] n_estimators=500, min_samples_split=10, min_samples_leaf=1, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=10, min_samples_leaf=1, max_features=auto, learning_rate=0.1, total= 1.3min
# [CV] n_estimators=500, min_samples_split=5, min_samples_leaf=10, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=5, min_samples_leaf=10, max_features=auto, learning_rate=0.1, total= 1.3min
# [CV] n_estimators=500, min_samples_split=5, min_samples_leaf=10, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=5, min_samples_leaf=10, max_features=auto, learning_rate=0.1, total= 1.2min
# [CV] n_estimators=500, min_samples_split=5, min_samples_leaf=10, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=5, min_samples_leaf=10, max_features=auto, learning_rate=0.1, total= 1.4min
# [CV] n_estimators=500, min_samples_split=5, min_samples_leaf=10, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=5, min_samples_leaf=10, max_features=auto, learning_rate=0.1, total= 1.3min
# [CV] n_estimators=500, min_samples_split=5, min_samples_leaf=10, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=5, min_samples_leaf=10, max_features=auto, learning_rate=0.1, total= 1.3min
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.05, total= 2.7min
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.05, total= 2.9min
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.05, total= 2.5min
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.05, total= 2.5min
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.05, total= 3.0min
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.01, total=  18.0s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.01, total=  18.8s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.01, total=  20.3s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.01, total=  19.8s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.01, total=  25.0s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.01, total= 1.7min
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.01, total= 1.6min
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.01, total= 1.4min
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.01, total= 1.2min
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.01, total= 1.3min
# [CV] n_estimators=50, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=50, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.01, total=   8.9s
# [CV] n_estimators=50, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=50, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.01, total=  10.4s
# [CV] n_estimators=50, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=50, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.01, total=  12.4s
# [CV] n_estimators=50, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=50, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.01, total=  15.4s
# [CV] n_estimators=50, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=50, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.01, total=  12.4s
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.01, total= 2.8min
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.01, total= 2.8min
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.01, total= 2.7min
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.01, total= 2.8min
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.01, total= 2.8min
# [CV] n_estimators=500, min_samples_split=5, min_samples_leaf=1, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=500, min_samples_split=5, min_samples_leaf=1, max_features=auto, learning_rate=0.05, total= 1.4min
# [CV] n_estimators=500, min_samples_split=5, min_samples_leaf=1, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=500, min_samples_split=5, min_samples_leaf=1, max_features=auto, learning_rate=0.05, total= 2.9min
# [CV] n_estimators=500, min_samples_split=5, min_samples_leaf=1, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=500, min_samples_split=5, min_samples_leaf=1, max_features=auto, learning_rate=0.05, total= 2.0min
# [CV] n_estimators=500, min_samples_split=5, min_samples_leaf=1, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=500, min_samples_split=5, min_samples_leaf=1, max_features=auto, learning_rate=0.05, total= 1.3min
# [CV] n_estimators=500, min_samples_split=5, min_samples_leaf=1, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=500, min_samples_split=5, min_samples_leaf=1, max_features=auto, learning_rate=0.05, total= 1.4min
# [CV] n_estimators=500, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=500, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.01, total= 1.4min
# [CV] n_estimators=500, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=500, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.01, total= 1.3min
# [CV] n_estimators=500, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=500, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.01, total= 1.4min
# [CV] n_estimators=500, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=500, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.01, total= 1.3min
# [CV] n_estimators=500, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=500, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.01, total= 1.3min
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.1, total= 1.2min
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.1, total= 1.3min
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.1, total= 1.3min
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.1, total= 1.3min
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.1, total= 1.5min
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.1, total= 1.3min
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.1, total= 1.4min
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.1, total= 1.4min
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.1, total= 1.4min
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.1, total= 1.3min
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.01, total=  18.9s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.01, total=  19.1s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.01, total=  18.1s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.01, total=  17.0s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.01, total=  16.6s
# [CV] n_estimators=500, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.1, total= 1.2min
# [CV] n_estimators=500, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.1, total= 1.6min
# [CV] n_estimators=500, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.1, total= 1.3min
# [CV] n_estimators=500, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.1, total= 1.4min
# [CV] n_estimators=500, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.1, total= 1.3min
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.01, total= 2.9min
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.01, total= 2.9min
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.01, total= 3.8min
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.01, total= 2.6min
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.01, total= 3.1min
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.01, total=   8.8s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.01, total=   8.1s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.01, total=   9.0s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.01, total=  11.0s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.01, total=  11.8s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=7, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=7, max_features=auto, learning_rate=0.01, total=  20.8s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=7, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=7, max_features=auto, learning_rate=0.01, total=  18.9s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=7, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=7, max_features=auto, learning_rate=0.01, total=  23.3s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=7, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=7, max_features=auto, learning_rate=0.01, total=  24.5s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=7, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=7, max_features=auto, learning_rate=0.01, total=  23.9s
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.1, total= 3.4min
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.1, total= 3.7min
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.1, total= 3.3min
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.1, total= 4.2min
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.1, total= 3.5min
# [CV] n_estimators=500, min_samples_split=5, min_samples_leaf=7, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=5, min_samples_leaf=7, max_features=auto, learning_rate=0.1, total= 1.1min
# [CV] n_estimators=500, min_samples_split=5, min_samples_leaf=7, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=5, min_samples_leaf=7, max_features=auto, learning_rate=0.1, total=  56.3s
# [CV] n_estimators=500, min_samples_split=5, min_samples_leaf=7, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=5, min_samples_leaf=7, max_features=auto, learning_rate=0.1, total=  56.0s
# [CV] n_estimators=500, min_samples_split=5, min_samples_leaf=7, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=5, min_samples_leaf=7, max_features=auto, learning_rate=0.1, total= 1.8min
# [CV] n_estimators=500, min_samples_split=5, min_samples_leaf=7, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=5, min_samples_leaf=7, max_features=auto, learning_rate=0.1, total= 2.3min
# [CV] n_estimators=500, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=500, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.05, total= 2.0min
# [CV] n_estimators=500, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=500, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.05, total=  51.3s
# [CV] n_estimators=500, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=500, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.05, total= 1.3min
# [CV] n_estimators=500, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=500, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.05, total= 1.2min
# [CV] n_estimators=500, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=500, min_samples_split=5, min_samples_leaf=3, max_features=auto, learning_rate=0.05, total= 1.4min
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=7, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=7, max_features=auto, learning_rate=0.01, total= 2.6min
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=7, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=7, max_features=auto, learning_rate=0.01, total= 2.5min
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=7, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=7, max_features=auto, learning_rate=0.01, total= 2.7min
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=7, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=7, max_features=auto, learning_rate=0.01, total= 2.8min
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=7, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=7, max_features=auto, learning_rate=0.01, total= 2.8min
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=1, max_features=auto, learning_rate=0.1
# ...
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.01, total=   3.8s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.01, total=   3.4s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.01, total=   3.4s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.05, total=  54.6s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.05, total=  29.6s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.05, total=  53.6s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.05, total=  29.4s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.05, total=  53.3s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.05, total=   3.4s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.05, total=   3.3s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.05, total=   3.2s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.05, total=   3.2s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.05, total=   3.3s
# [CV] n_estimators=1000, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=1000, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.05, total= 1.4min
# [CV] n_estimators=1000, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=1000, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.05, total= 1.4min
# [CV] n_estimators=1000, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=1000, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.05, total= 1.4min
# [CV] n_estimators=1000, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=1000, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.05, total= 1.4min
# [CV] n_estimators=1000, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=1000, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.05, total= 1.4min
# [CV] n_estimators=1000, min_samples_split=10, min_samples_leaf=1, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=1000, min_samples_split=10, min_samples_leaf=1, max_features=auto, learning_rate=0.05, total= 1.4min
# [CV] n_estimators=1000, min_samples_split=10, min_samples_leaf=1, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=1000, min_samples_split=10, min_samples_leaf=1, max_features=auto, learning_rate=0.05, total= 1.2min
# [CV] n_estimators=1000, min_samples_split=10, min_samples_leaf=1, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=1000, min_samples_split=10, min_samples_leaf=1, max_features=auto, learning_rate=0.05, total= 1.4min
# [CV] n_estimators=1000, min_samples_split=10, min_samples_leaf=1, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=1000, min_samples_split=10, min_samples_leaf=1, max_features=auto, learning_rate=0.05, total= 1.2min
# [CV] n_estimators=1000, min_samples_split=10, min_samples_leaf=1, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=1000, min_samples_split=10, min_samples_leaf=1, max_features=auto, learning_rate=0.05, total= 1.4min
# [CV] n_estimators=500, min_samples_split=10, min_samples_leaf=3, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=10, min_samples_leaf=3, max_features=auto, learning_rate=0.1, total=  35.4s
# [CV] n_estimators=500, min_samples_split=10, min_samples_leaf=3, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=10, min_samples_leaf=3, max_features=auto, learning_rate=0.1, total=  40.2s
# [CV] n_estimators=500, min_samples_split=10, min_samples_leaf=3, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=10, min_samples_leaf=3, max_features=auto, learning_rate=0.1, total=  43.9s
# [CV] n_estimators=500, min_samples_split=10, min_samples_leaf=3, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=10, min_samples_leaf=3, max_features=auto, learning_rate=0.1, total=  32.8s
# [CV] n_estimators=500, min_samples_split=10, min_samples_leaf=3, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=10, min_samples_leaf=3, max_features=auto, learning_rate=0.1, total=  48.1s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.05, total=   6.4s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.05, total=   6.1s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.05, total=   6.2s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.05, total=   6.0s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.05, total=   8.5s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.01, total=  18.5s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.01, total=  14.9s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.01, total=   6.8s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.01, total=   7.0s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.01, total=   7.1s
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=1, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=1, max_features=auto, learning_rate=0.01, total= 1.4min
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=1, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=1, max_features=auto, learning_rate=0.01, total= 1.4min
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=1, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=1, max_features=auto, learning_rate=0.01, total= 1.4min
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=1, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=1, max_features=auto, learning_rate=0.01, total= 1.4min
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=1, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=1, max_features=auto, learning_rate=0.01, total= 1.4min
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.1, total=   3.0s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.1, total=   3.0s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.1, total=   3.1s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.1, total=   3.3s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.1, total=   3.0s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.1, total=  43.0s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.1, total=  37.3s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.1, total=  47.0s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.1, total=  31.8s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.1, total=  44.4s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=7, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=7, max_features=auto, learning_rate=0.1, total=  11.5s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=7, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=7, max_features=auto, learning_rate=0.1, total=   6.3s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=7, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=7, max_features=auto, learning_rate=0.1, total=   6.4s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=7, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=7, max_features=auto, learning_rate=0.1, total=   6.0s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=7, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=7, max_features=auto, learning_rate=0.1, total=   6.1s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=3, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=3, max_features=auto, learning_rate=0.01, total=   7.2s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=3, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=3, max_features=auto, learning_rate=0.01, total=   7.0s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=3, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=3, max_features=auto, learning_rate=0.01, total=  16.9s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=3, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=3, max_features=auto, learning_rate=0.01, total=  19.4s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=3, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=3, max_features=auto, learning_rate=0.01, total=   7.6s
# [CV] n_estimators=500, min_samples_split=10, min_samples_leaf=7, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=10, min_samples_leaf=7, max_features=auto, learning_rate=0.1, total=  29.7s
# [CV] n_estimators=500, min_samples_split=10, min_samples_leaf=7, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=10, min_samples_leaf=7, max_features=auto, learning_rate=0.1, total=  54.9s
# [CV] n_estimators=500, min_samples_split=10, min_samples_leaf=7, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=10, min_samples_leaf=7, max_features=auto, learning_rate=0.1, total=  29.4s
# [CV] n_estimators=500, min_samples_split=10, min_samples_leaf=7, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=10, min_samples_leaf=7, max_features=auto, learning_rate=0.1, total=  54.4s
# [CV] n_estimators=500, min_samples_split=10, min_samples_leaf=7, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=10, min_samples_leaf=7, max_features=auto, learning_rate=0.1, total=  29.4s
# [Parallel(n_jobs=1)]: Done 500 out of 500 | elapsed: 479.7min finished
# RandomizedSearchCV(cv=5, error_score='raise-deprecating',
#           estimator=GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#              learning_rate=0.1, loss='ls', max_depth=3, max_features=None,
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_sampl...te=42, subsample=1.0, tol=0.0001,
#              validation_fraction=0.1, verbose=0, warm_start=False),
#           fit_params=None, iid='warn', n_iter=100, n_jobs=None,
#           param_distributions={'n_estimators': [50, 100, 500, 1000], 'learning_rate': [0.01, 0.05, 0.1], 'max_features': ['auto'], 'min_samples_leaf': [1, 3, 7, 10], 'min_samples_split': [2, 5, 10]},
#           pre_dispatch='2*n_jobs', random_state=None, refit=True,
#           return_train_score='warn',
#           scoring=make_scorer(rmse, greater_is_better=False), verbose=2)

# %%
print('Best parameters for Gradient Boost Model: {}'.format(grad_boost.best_params_))
# Out:
# Best parameters for Gradient Boost Model: {'n_estimators': 500, 'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_depth': 60, 'learning_rate': 0.01}

# %% [markdown]
# Best parameters for Gradient Boost Model: {'n_estimators': 500, 'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_depth': 60, 'learning_rate': 0.01}

# %%
# Following code uses the best parameters generated above to fit the model

from sklearn.ensemble import GradientBoostingRegressor

param_distributions = {'n_estimators': [500], 'learning_rate':[0.01],'max_features':['sqrt'], 'min_samples_leaf':[10], 'max_depth':[60], 'min_samples_split':[2]}
grad_boost = RandomizedSearchCV(GradientBoostingRegressor(random_state=42), param_distributions, n_iter = 100,cv=5, scoring=rmse_cv)
# %time grad_boost.fit(X_train, y_train)
# Out:
# C:\Users\sony\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:271: UserWarning: The total space of parameters 1 is smaller than n_iter=100. Running 1 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# Wall time: 1min 29s
# RandomizedSearchCV(cv=5, error_score='raise-deprecating',
#           estimator=GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#              learning_rate=0.1, loss='ls', max_depth=3, max_features=None,
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_sampl...te=42, subsample=1.0, tol=0.0001,
#              validation_fraction=0.1, verbose=0, warm_start=False),
#           fit_params=None, iid='warn', n_iter=100, n_jobs=None,
#           param_distributions={'n_estimators': [500], 'learning_rate': [0.01], 'max_features': ['sqrt'], 'min_samples_leaf': [10], 'max_depth': [60], 'min_samples_split': [2]},
#           pre_dispatch='2*n_jobs', random_state=None, refit=True,
#           return_train_score='warn',
#           scoring=make_scorer(rmse, greater_is_better=False), verbose=0)

# %%
print('Best parameters for Gradient Boost Model: {}'.format(grad_boost.best_params_))
# Out:
# Best parameters for Gradient Boost Model: {'n_estimators': 500, 'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_depth': 60, 'learning_rate': 0.01}

# %%
param_summary = [grad_boost.best_params_,'']

# %time rmse_summary, y_predict_summary = model_fit(grad_boost, X_train, y_train, X_test, y_test)
ypred_test['GB'] = y_predict_summary[1]
ypred_train['GB'] = y_predict_summary[0]

algo_score.loc['Gradient Boost'] = rmse_summary+param_summary
# Out:
# Wall time: 796 ms

# %%
algo_score.loc['Gradient Boost', 'Training+Test Time(sec)'] = 89.796
cv_time.append(89.796)
algo_score
# Out:
#                    Train RMSE  Test RMSE  \
# Modelling Algo
# Linear Regression    0.889720   0.903349
# Ridge Regression     0.890131   0.902272
# Lasso Regression     0.913179   0.919122
# Random Forest        0.300850   0.630694
# Gradient Boost       0.324200   0.624689
#
#                                                      Hyperparameters  \
# Modelling Algo
# Linear Regression
# Ridge Regression                                     {'alpha': 2.75}
# Lasso Regression                                     {'alpha': 0.01}
# Random Forest      {'n_estimators': 5000, 'min_samples_split': 10...
# Gradient Boost     {'n_estimators': 500, 'min_samples_split': 2, ...
#
#                   Training+Test Time(sec)
# Modelling Algo
# Linear Regression                   0.214
# Ridge Regression                    5.414
# Lasso Regression                   59.968
# Random Forest                       662.8
# Gradient Boost                     89.796

# %% [markdown]
# ### Visualize the mean score against different values for n estimators
#
# Parts of code have been commenting out as they take long time to execute

# %%
# gb_result=pd.DataFrame(grad_boost.cv_results_)
# gb_result
# Out:
# C:\Users\sony\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split0_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\sony\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split1_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\sony\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split2_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\sony\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split3_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\sony\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split4_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\sony\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\sony\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('std_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0      510.893427     67.511128         9.985637        3.343835
# 1      258.975860     55.644187         3.189319        1.838653
# 2      401.780482     67.610470         0.750660        0.241365
# 3        2.336185      0.143692         0.043775        0.003321
# 4       28.480963      0.595264         0.233108        0.021268
# 5        3.149409      0.581806         0.054560        0.012335
# 6       46.301529      8.772028         0.277563        0.037576
# 7       34.440285      8.870836         0.391511        0.166496
# 8      711.151508    378.098870         1.940364        1.694838
# 9        5.134262      1.823835         0.097850        0.070642
# 10       3.392781      1.038954         0.034247        0.012035
# 11       5.750118      0.186075         0.077160        0.001467
# 12       9.566590      0.878990         0.097762        0.008861
# 13      25.558098     14.213460         0.041377        0.005306
# 14      21.854812     11.681482         0.033781        0.023114
# 15       0.996686      0.109686         0.016784        0.002976
# 16      17.837372     14.330536         0.071366        0.032542
# 17      29.709027     17.393411         0.032009        0.005599
# 18      69.329626     20.976946         0.769626        0.697252
# 19      23.004885      8.589693         0.319982        0.210806
# 20      17.979826      7.753257         0.233007        0.211383
# 21      27.094828     12.660605         0.053377        0.046314
# 22     251.772670     44.164939         0.230801        0.087994
# 23      74.500344     16.267680         0.111736        0.002227
# 24      97.028633      9.751523         0.175699        0.005525
# 25      16.478541      7.010360         0.176504        0.010248
# 26      18.745813      5.410971         0.269651        0.177523
# 27       1.419354      0.035614         0.017594        0.002329
# 28       6.827350      0.358004         0.060557        0.001488
# 29       6.357969      0.444203         0.016597        0.001190
# ..            ...           ...              ...             ...
# 70      22.882784      0.083323         0.028982        0.000639
# 71     145.909832      9.413367         0.132733        0.004528
# 72      30.488078      0.378534         0.233474        0.009970
# 73     106.252338      9.599679         0.221673        0.062171
# 74       7.766400      0.180456         0.096596        0.007750
# 75     791.129503    243.023263         2.104695        0.874276
# 76     176.303200     33.075062         0.174307        0.099228
# 77       5.759413      0.203590         0.033590        0.002240
# 78      63.278576      5.517335         0.095153        0.002784
# 79      13.618902      3.255475         0.195092        0.102568
# 80     246.593963     15.435213         0.487149        0.059419
# 81      10.066208      0.266728         0.104547        0.011536
# 82      33.266820     11.830071         0.286040        0.168965
# 83      27.888636     12.807109         0.027383        0.000500
# 84       7.363881      0.559186         0.064969        0.003629
# 85      31.419324     10.706955         0.205477        0.019518
# 86      11.547303      5.462219         0.049785        0.032078
# 87       1.929738      0.101058         0.018390        0.001958
# 88      36.387623     11.659623         0.088356        0.085292
# 89      92.231695     20.628266         0.149559        0.014933
# 90      19.492692      0.746723         0.170451        0.018470
# 91      50.815263      8.428947         0.435748        0.030376
# 92      17.032482      6.434533         0.019389        0.001341
# 93       2.143477      0.298420         0.025786        0.002712
# 94       2.616991      0.032831         0.028784        0.000748
# 95      12.349012      0.405542         0.163106        0.010449
# 96     235.956574      6.716413         0.427556        0.027360
# 97      26.840550      5.758200         0.134720        0.014213
# 98       8.860432      1.553148         0.021188        0.002637
# 99       4.851748      1.239767         0.058768        0.012601
#
#    param_n_estimators param_min_samples_split param_min_samples_leaf  \
# 0                5000                       5                      7
# 1                2000                       2                      1
# 2                2000                       2                      3
# 3                  50                      10                     10
# 4                 250                       5                      3
# 5                  50                      10                     10
# 6                1000                       5                      1
# 7                 250                      10                      1
# 8                2000                      10                      1
# 9                  50                       5                     10
# 10                100                      10                     10
# 11                500                       5                     10
# 12                500                      10                      7
# 13                250                      10                      3
# 14                 50                       5                      3
# 15                 50                      10                      7
# 16                100                       2                      1
# 17                100                      10                      1
# 18               2000                      10                      7
# 19               1000                      10                     10
# 20               1000                      10                     10
# 21                100                       5                     10
# 22               5000                       5                      1
# 23                500                       5                      7
# 24               2000                      10                     10
# 25               1000                       2                     10
# 26               1000                      10                      7
# 27                 50                       2                      3
# 28                250                       5                      3
# 29                 50                       5                      7
# ..                ...                     ...                    ...
# 70                100                       5                      1
# 71                500                       5                      1
# 72               2000                       5                      1
# 73               2000                      10                      1
# 74                500                       2                      7
# 75               5000                      10                      7
# 76               5000                       2                      1
# 77                500                       2                      1
# 78                500                      10                     10
# 79                500                      10                      3
# 80               2000                      10                      7
# 81                500                       5                      3
# 82               1000                       2                      7
# 83                100                       2                      3
# 84                250                      10                      1
# 85               2000                       5                      7
# 86                250                       2                      1
# 87                 50                       5                      3
# 88                100                      10                      3
# 89                500                       2                     10
# 90               1000                       5                      3
# 91               2000                      10                      7
# 92                 50                       5                      1
# 93                100                      10                      3
# 94                100                      10                      1
# 95               1000                       2                      7
# 96               2000                      10                      3
# 97                500                      10                      1
# 98                 50                       2                     10
# 99                100                       2                      7
#
#    param_max_features param_max_depth param_learning_rate       ...         \
# 0                log2              40                0.01       ...
# 1                log2              40                0.01       ...
# 2                auto              80                0.05       ...
# 3                log2             100                0.05       ...
# 4                sqrt              80                 0.1       ...
# 5                log2              70                0.05       ...
# 6                log2              60                0.05       ...
# 7                log2              40                0.01       ...
# 8                auto              50                0.01       ...
# 9                log2              70                0.01       ...
# 10               sqrt              90                0.01       ...
# 11               log2              20                 0.1       ...
# 12               sqrt              20                0.05       ...
# 13               auto              10                0.05       ...
# 14               auto              60                0.05       ...
# 15               log2             100                0.02       ...
# 16               log2              70                0.01       ...
# 17               auto              70                0.05       ...
# 18               sqrt              70                0.05       ...
# 19               log2              60                 0.1       ...
# 20               sqrt              10                 0.1       ...
# 21               auto              30                0.02       ...
# 22               auto              20                0.02       ...
# 23               auto              30                0.05       ...
# 24               auto              10                0.01       ...
# 25               log2              80                0.02       ...
# 26               log2              80                 0.1       ...
# 27               log2             100                0.01       ...
# 28               log2              30                0.05       ...
# 29               auto              50                0.02       ...
# ..                ...             ...                 ...       ...
# 70               auto              30                 0.1       ...
# 71               auto              50                0.01       ...
# 72               log2              20                0.02       ...
# 73               auto              10                0.02       ...
# 74               log2              60                0.02       ...
# 75               auto              30                0.02       ...
# 76               auto             100                0.05       ...
# 77               log2              80                 0.1       ...
# 78               auto              50                0.01       ...
# 79               log2              30                0.05       ...
# 80               auto              30                0.02       ...
# 81               log2              70                 0.1       ...
# 82               sqrt              30                0.01       ...
# 83               auto              50                0.01       ...
# 84               log2              60                0.02       ...
# 85               sqrt              40                 0.1       ...
# 86               sqrt              20                 0.1       ...
# 87               sqrt              40                 0.1       ...
# 88               auto              90                0.01       ...
# 89               auto             100                 0.1       ...
# 90               sqrt             100                0.05       ...
# 91               sqrt             100                0.02       ...
# 92               auto              90                0.02       ...
# 93               log2              20                0.02       ...
# 94               log2              40                 0.1       ...
# 95               log2              20                0.05       ...
# 96               auto              40                0.02       ...
# 97               sqrt              30                0.01       ...
# 98               auto             100                0.05       ...
# 99               sqrt              50                0.02       ...
#
#    mean_test_score  std_test_score  rank_test_score  split0_train_score  \
# 0        -0.647027        0.020475               17           -0.013342
# 1        -0.648052        0.024402               19           -0.000316
# 2        -0.695136        0.031662               81           -0.000331
# 3        -0.660620        0.022577               50           -0.507276
# 4        -0.652837        0.018988               31           -0.001662
# 5        -0.660620        0.022577               50           -0.507276
# 6        -0.650380        0.023463               27           -0.000315
# 7        -0.650605        0.023479               28           -0.215377
# 8        -0.699013        0.029941               84           -0.000316
# 9        -0.925008        0.027329              100           -0.896067
# 10       -0.763226        0.026413               94           -0.686886
# 11       -0.670013        0.018277               64           -0.044814
# 12       -0.654996        0.022080               36           -0.050442
# 13       -0.660918        0.022568               53           -0.199012
# 14       -0.694258        0.029439               79           -0.154341
# 15       -0.778235        0.026878               96           -0.697598
# 16       -0.763606        0.027493               95           -0.433228
# 17       -0.699949        0.030776               85           -0.028739
# 18       -0.653549        0.022240               33           -0.000685
# 19       -0.669241        0.020666               63           -0.007810
# 20       -0.676458        0.017735               69           -0.051449
# 21       -0.664746        0.023791               57           -0.411371
# 22       -0.734500        0.030211               86           -0.000316
# 23       -0.675848        0.023696               68           -0.019167
# 24       -0.659056        0.022768               45           -0.202036
# 25       -0.645627        0.019972               16           -0.128775
# 26       -0.663047        0.019794               54           -0.002401
# 27       -0.907624        0.026922               99           -0.830398
# 28       -0.648875        0.021490               22           -0.030554
# 29       -0.748992        0.024962               89           -0.575657
# ..             ...             ...              ...                 ...
# 70       -0.740376        0.029059               88           -0.000341
# 71       -0.736585        0.033489               87           -0.010766
# 72       -0.644600        0.025565               13           -0.000316
# 73       -0.665824        0.028969               59           -0.018997
# 74       -0.639614        0.022260                7           -0.182214
# 75       -0.677593        0.023859               74           -0.001717
# 76       -0.869325        0.035302               98           -0.000316
# 77       -0.663704        0.024465               56           -0.000316
# 78       -0.658087        0.021299               42           -0.200677
# 79       -0.649788        0.020333               25           -0.009121
# 80       -0.677072        0.023971               72           -0.010686
# 81       -0.654466        0.020560               34           -0.000541
# 82       -0.637243        0.019468                5           -0.135958
# 83       -0.760843        0.027781               92           -0.486954
# 84       -0.642520        0.021635               10           -0.070411
# 85       -0.659409        0.019633               46           -0.000316
# 86       -0.657717        0.019122               41           -0.000312
# 87       -0.650040        0.019073               26           -0.098263
# 88       -0.754597        0.028053               91           -0.514941
# 89       -0.677659        0.025045               75           -0.013061
# 90       -0.650842        0.021693               29           -0.000316
# 91       -0.648467        0.020888               21           -0.011604
# 92       -0.782777        0.018218               97           -0.445598
# 93       -0.666100        0.024858               61           -0.408120
# 94       -0.656539        0.019949               38           -0.014888
# 95       -0.660338        0.019306               48           -0.020467
# 96       -0.682329        0.029673               78           -0.000767
# 97       -0.636551        0.022429                4           -0.058755
# 98       -0.658964        0.023694               44           -0.354460
# 99       -0.657697        0.023559               39           -0.459805
#
#     split1_train_score  split2_train_score  split3_train_score  \
# 0            -0.013798           -0.017732           -0.013620
# 1            -0.000316           -0.000316           -0.000316
# 2            -0.000316           -0.000321           -0.000316
# 3            -0.507748           -0.511990           -0.506550
# 4            -0.001478           -0.002305           -0.002035
# 5            -0.507748           -0.511990           -0.506550
# 6            -0.000315           -0.000316           -0.000315
# 7            -0.214764           -0.217153           -0.215937
# 8            -0.000316           -0.000316           -0.000316
# 9            -0.896319           -0.899935           -0.897228
# 10           -0.686914           -0.689699           -0.685211
# 11           -0.044457           -0.053773           -0.043399
# 12           -0.049829           -0.054524           -0.051793
# 13           -0.186146           -0.184646           -0.152656
# 14           -0.152833           -0.161421           -0.153886
# 15           -0.698057           -0.701841           -0.694092
# 16           -0.434396           -0.434497           -0.435710
# 17           -0.026182           -0.027115           -0.024894
# 18           -0.001071           -0.001436           -0.000786
# 19           -0.008448           -0.011612           -0.008303
# 20           -0.050523           -0.062236           -0.051429
# 21           -0.403184           -0.413219           -0.402382
# 22           -0.000316           -0.000316           -0.000316
# 23           -0.017435           -0.035681           -0.018369
# 24           -0.216923           -0.255259           -0.202653
# 25           -0.129427           -0.136856           -0.129648
# 26           -0.002133           -0.003417           -0.002724
# 27           -0.829612           -0.831757           -0.830704
# 28           -0.029413           -0.032956           -0.028444
# 29           -0.573203           -0.581423           -0.577776
# ..                 ...                 ...                 ...
# 70           -0.000320           -0.000336           -0.000325
# 71           -0.010651           -0.011043           -0.011014
# 72           -0.000316           -0.000316           -0.000316
# 73           -0.020600           -0.023931           -0.021425
# 74           -0.176929           -0.187621           -0.176869
# 75           -0.001325           -0.004656           -0.001440
# 76           -0.000316           -0.000316           -0.000316
# 77           -0.000316           -0.000316           -0.000315
# 78           -0.194564           -0.204623           -0.195246
# 79           -0.008532           -0.011448           -0.009397
# 80           -0.008661           -0.024052           -0.009747
# 81           -0.000354           -0.000651           -0.000527
# 82           -0.131759           -0.141596           -0.133907
# 83           -0.487892           -0.495705           -0.490570
# 84           -0.066779           -0.071366           -0.071147
# 85           -0.000316           -0.000316           -0.000316
# 86           -0.000313           -0.000315           -0.000316
# 87           -0.092263           -0.101445           -0.098446
# 88           -0.513577           -0.520368           -0.516733
# 89           -0.024400           -0.028034           -0.016554
# 90           -0.000315           -0.000316           -0.000316
# 91           -0.013364           -0.015929           -0.011093
# 92           -0.446999           -0.446823           -0.450236
# 93           -0.405432           -0.409550           -0.407634
# 94           -0.013681           -0.015932           -0.015285
# 95           -0.023038           -0.025336           -0.021678
# 96           -0.001607           -0.001498           -0.001819
# 97           -0.056186           -0.059523           -0.058561
# 98           -0.344566           -0.355277           -0.343864
# 99           -0.455490           -0.463263           -0.454999
#
#     split4_train_score  mean_train_score  std_train_score
# 0            -0.014581         -0.014615     1.612103e-03
# 1            -0.000316         -0.000316     3.253691e-08
# 2            -0.000315         -0.000320     5.933798e-06
# 3            -0.501007         -0.506914     3.510745e-03
# 4            -0.002126         -0.001921     3.051967e-04
# 5            -0.501007         -0.506914     3.510745e-03
# 6            -0.000316         -0.000315     5.539515e-07
# 7            -0.212524         -0.215151     1.531302e-03
# 8            -0.000316         -0.000316     9.377344e-08
# 9            -0.882938         -0.894497     5.940093e-03
# 10           -0.678075         -0.685357     3.915922e-03
# 11           -0.049126         -0.047114     3.861192e-03
# 12           -0.057256         -0.052769     2.765004e-03
# 13           -0.177076         -0.179907     1.534292e-02
# 14           -0.152434         -0.154983     3.292188e-03
# 15           -0.685768         -0.695471     5.437685e-03
# 16           -0.428009         -0.433168     2.696609e-03
# 17           -0.024881         -0.026362     1.456010e-03
# 18           -0.001207         -0.001037     2.743531e-04
# 19           -0.008981         -0.009031     1.343289e-03
# 20           -0.057395         -0.054606     4.532645e-03
# 21           -0.397764         -0.405584     5.812875e-03
# 22           -0.000316         -0.000316     9.103247e-08
# 23           -0.028180         -0.023766     7.096553e-03
# 24           -0.230540         -0.221482     1.988162e-02
# 25           -0.128368         -0.130615     3.153766e-03
# 26           -0.002375         -0.002610     4.449704e-04
# 27           -0.816312         -0.827757     5.763409e-03
# 28           -0.029789         -0.030231     1.522552e-03
# 29           -0.568118         -0.575235     4.465382e-03
# ..                 ...               ...              ...
# 70           -0.000317         -0.000328     9.246191e-06
# 71           -0.010528         -0.010800     2.010484e-04
# 72           -0.000316         -0.000316     8.146275e-08
# 73           -0.023989         -0.021788     1.937489e-03
# 74           -0.176790         -0.180085     4.300656e-03
# 75           -0.001590         -0.002146     1.262330e-03
# 76           -0.000316         -0.000316     1.234980e-07
# 77           -0.000316         -0.000316     3.156108e-07
# 78           -0.189955         -0.197013     5.104270e-03
# 79           -0.009604         -0.009621     9.824526e-04
# 80           -0.016120         -0.013853     5.709582e-03
# 81           -0.000341         -0.000483     1.186629e-04
# 82           -0.134108         -0.135465     3.341776e-03
# 83           -0.483291         -0.488882     4.131688e-03
# 84           -0.067551         -0.069451     1.908455e-03
# 85           -0.000316         -0.000316     1.986223e-07
# 86           -0.000314         -0.000314     1.421663e-06
# 87           -0.095046         -0.097092     3.151757e-03
# 88           -0.509206         -0.514965     3.671570e-03
# 89           -0.022327         -0.020875     5.394764e-03
# 90           -0.000316         -0.000316     4.451437e-07
# 91           -0.013587         -0.013116     1.707554e-03
# 92           -0.440577         -0.446046     3.136052e-03
# 93           -0.399893         -0.406126     3.385564e-03
# 94           -0.011991         -0.014355     1.391386e-03
# 95           -0.023285         -0.022761     1.638203e-03
# 96           -0.001233         -0.001385     3.620692e-04
# 97           -0.055126         -0.057630     1.677477e-03
# 98           -0.339084         -0.347450     6.349302e-03
# 99           -0.453720         -0.457455     3.552436e-03
#
# [100 rows x 26 columns]

# %%
# gb_score = gb_result.groupby('param_n_estimators')['mean_test_score'].mean()
# gb_score
# Out:
# param_n_estimators
# 50     -0.724405
# 100    -0.700721
# 250    -0.657044
# 500    -0.659686
# 1000   -0.662805
# 2000   -0.661782
# 5000   -0.685242
# Name: mean_test_score, dtype: float64

# %%
# fig=plt.figure(figsize=(18, 12))

# axes=fig.add_subplot(2, 3, 1)
# axes.plot(gb_score.index, gb_score.values, marker='.')
# axes.set(xlabel='n_estimators', ylabel='Mean CV Test Score', title='n_estimators vs. Score (best_n_estimator = 500)')
# Out:
# [Text(0,0.5,'Mean CV Test Score'),
#  Text(0.5,0,'n_estimators'),
#  Text(0.5,1,'n_estimators vs. Score (best_n_estimator = 500)')]

# %%
fig = plt.figure(figsize=(18, 8))
axes = fig.add_subplot(1, 1, 1)
axes.plot(grad_boost.best_estimator_.feature_importances_, marker='.', markersize=15)
plt.xticks(range(len(grad_boost.best_estimator_.feature_importances_)), X_train.columns,rotation=90)
axes.set(ylabel='Feature Importance', title='Feature Importance for Gradient Boost Regressor')
# axes.set(xlim=[-1, len(X_train.columns)], ylim=[0, 1])

plt.show()

# %% [markdown]
# ## SUMMARY AND CONCLUSIONS

# %% [markdown]
# ### RMSE

# %%
fig=plt.figure(figsize=(10, 6))
axes=fig.add_subplot(1, 1, 1)
bar_width = 0.3
idx = np.array(range(algo_score.shape[0]))
labels = algo_score.index
plt.bar(data=algo_score, height='Train RMSE', x=idx, color='g', width=bar_width, label='Training Data')
plt.bar(data=algo_score, height='Test RMSE', x=idx+bar_width, color='b', width=bar_width, label='Test Data')
plt.xticks(idx, labels, rotation=90)
plt.xlabel('Modelling Algorithms')
plt.ylabel('RMSE')
plt.title('Average RMSE for different Modelling Algorithms')
plt.legend()
plt.show()

# %% [markdown]
# From the above plot, we can see that Random Forest and Gradient Boost give us very similar and the best predictions with least RMSE. Comparing the train and test data predictions, the model seems to be be overfitted. But we are not much worried about it, as despite overfitting, we are getting good results on the test data.
#
# In order to decide between Random Forest and Gradient Boost, let us look at the time taken in fitting the model. In all the algorithms, the prediction time was very small in comparison to the fit time.

# %% [markdown]
# ### Train/Test Time

# %%
fig=plt.figure(figsize=(10, 6))
axes=fig.add_subplot(1, 1, 1)
bar_width = 0.6
idx = np.array(range(algo_score.shape[0]))
labels = algo_score.index
plt.bar(data=algo_score, height='Training+Test Time(sec)', x=idx, width=bar_width)
plt.xticks(idx, labels, rotation=90)
plt.xlabel('Modelling Algorithms')
plt.ylabel('Training+Test Time(sec)')
plt.title('Training Time + Test Time for different Models (sec)')
#axes.set_yscale('log')
plt.show()

# %% [markdown]
# As seen above, Gradient Boost is taking much lesser time as compared to Random Forest. So we choose Gradient Boost as our final algorithm.
# Gradient Boost gives an RMSE of 0.625 on our test data.

# %% [markdown]
# References:
#
# https://www.analyticsvidhya.com/blog/2018/06/comprehensive-guide-for-ensemble-models/
#
# https://towardsdatascience.com/hyperparameter-tuning-the-random-forest-in-python-using-scikit-learn-28d2aa77dd74
